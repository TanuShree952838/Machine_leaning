# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = plt.imread("groupphoto.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (501, 751, 3)

# %%
model = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
faces = model.detectMultiScale(img)

# %%
faces
# Out:
# array([[491,  96,  64,  64],
#        [272, 245,  69,  69],
#        [311, 129,  62,  62],
#        [196, 124,  64,  64],
#        [390, 123,  66,  66],
#        [419, 227,  68,  68]], dtype=int32)

# %%
faces.shape
# Out:
# (6, 4)

# %%
for face in faces:
  x,y,w,h = face

  img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2 )

# %%
plt.imshow(img)

# %% [markdown]
# #Task 5
#
# Name: Tanushree Sharma
#
# Reg. No.: GO_STP_928

# %%
import numpy as np
import pandas as pd

# %% [raw]
# 1. Load the IMDb Dataset and read

# %%
df = pd.read_csv("IMDB-Movie-Data.csv")

# %% [raw]
# 2. View the dataset

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head() #First five rows
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.tail() #Last 5 rows
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %% [raw]
# 3. Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.

# %%
df.size #number of elements
# Out:
# 12000

# %%
df.shape #return a tuple representing the dimensionality
# Out:
# (1000, 12)

# %%
df.dtypes #Data types
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.columns #List the type of columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.ndim #Number of dimensions
# Out:
# 2

# %%
df.describe() #generate descriptive statistics (for numeric columns only)
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 74.3+ KB

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df.empty
# Out:
# False

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#         'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#         'Metascore'],
#        dtype='object')]

# %% [raw]
# 4. Data Selection – Indexing and Slicing data

# %%
df[["Rank", "Director"]] # indexing
# Out:
#      Rank              Director
# 0       1            James Gunn
# 1       2          Ridley Scott
# 2       3    M. Night Shyamalan
# 3       4  Christophe Lourdelet
# 4       5            David Ayer
# ..    ...                   ...
# 995   996             Billy Ray
# 996   997              Eli Roth
# 997   998            Jon M. Chu
# 998   999        Scot Armstrong
# 999  1000      Barry Sonnenfeld
#
# [1000 rows x 2 columns]

# %%
print("Top 5 Movies and it's directors")
df.loc[:5, ["Title", "Director"]]
# Out:
# Top 5 Movies and it's directors
#                      Title              Director
# 0  Guardians of the Galaxy            James Gunn
# 1               Prometheus          Ridley Scott
# 2                    Split    M. Night Shyamalan
# 3                     Sing  Christophe Lourdelet
# 4            Suicide Squad            David Ayer
# 5           The Great Wall           Yimou Zhang

# %%
df.iloc[-10:, 8]
# Out:
# 990    6.6
# 991    8.5
# 992    6.3
# 993    5.9
# 994    6.7
# 995    6.2
# 996    5.5
# 997    6.2
# 998    5.6
# 999    5.3
# Name: Rating, dtype: float64

# %% [raw]
# 5. Data Selection – Based on Conditional filtering

# %%
print("Movies with 6+ Rating")
movies = df.loc[(df["Rating"] > 6), ["Title", "Director", "Rating", "Year"]]
movies
# Out:
# Movies with 6+ Rating
#                        Title              Director  Rating  Year
# 0    Guardians of the Galaxy            James Gunn     8.1  2014
# 1                 Prometheus          Ridley Scott     7.0  2012
# 2                      Split    M. Night Shyamalan     7.3  2016
# 3                       Sing  Christophe Lourdelet     7.2  2016
# 4              Suicide Squad            David Ayer     6.2  2016
# ..                       ...                   ...     ...   ...
# 991         Taare Zameen Par            Aamir Khan     8.5  2007
# 992     Take Me Home Tonight         Michael Dowse     6.3  2011
# 994                Project X       Nima Nourizadeh     6.7  2012
# 995     Secret in Their Eyes             Billy Ray     6.2  2015
# 997   Step Up 2: The Streets            Jon M. Chu     6.2  2008
#
# [790 rows x 4 columns]

# %%
print("Movies with 6+ Rating directed by Christopher Nolan")
movies.loc[(movies["Director"] == "Christopher Nolan"), ["Title", "Rating"]]
# Out:
# Movies with 6+ Rating directed by Christopher Nolan
#                      Title  Rating
# 36            Interstellar     8.6
# 54         The Dark Knight     9.0
# 64            The Prestige     8.5
# 80               Inception     8.8
# 124  The Dark Knight Rises     8.5

# %%
print("Movies released in 2015 with a rating of 6+")
df[(df["Year"] == 2015) & (df["Rating"] > 6)]
# Out:
# Movies released in 2015 with a rating of 6+
#      Rank                                       Title  \
# 26     27                     Bahubali: The Beginning
# 50     51  Star Wars: Episode VII - The Force Awakens
# 67     68                          Mad Max: Fury Road
# 84     85                               Furious Seven
# 85     86                              Jurassic World
# ..    ...                                         ...
# 950   951              Me and Earl and the Dying Girl
# 967   968                                    The Walk
# 976   977                                 Dark Places
# 984   985                                         Max
# 995   996                        Secret in Their Eyes
#
#                          Genre  \
# 26      Action,Adventure,Drama
# 50    Action,Adventure,Fantasy
# 67     Action,Adventure,Sci-Fi
# 84       Action,Crime,Thriller
# 85     Action,Adventure,Sci-Fi
# ..                         ...
# 950               Comedy,Drama
# ...

# %% [raw]
# 6. Groupby operations

# %%
df.groupby("Director")["Rating"].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %%
print("Number of movies released in each year")
df.groupby("Year")["Year"].count()
# Out:
# Number of movies released in each year
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Year, dtype: int64

# %% [raw]
# 7. Sorting operation

# %%
print("Number of movies in each year without Sorting")
df.groupby("Year", sort = False)["Year"].count()
# Out:
# Number of movies in each year without Sorting
# Year
# 2014     98
# 2012     64
# 2016    297
# 2015    127
# 2007     53
# 2011     63
# 2008     52
# 2006     44
# 2009     51
# 2010     60
# 2013     91
# Name: Year, dtype: int64

# %%
print("Movies with 6+ Rating sorted by Year of release")
movies.sort_values("Year")
# Out:
# Movies with 6+ Rating sorted by Year of release
#                                            Title         Director  Rating  \
# 593                                She's the Man     Andy Fickman     6.4
# 99                                  The Departed  Martin Scorsese     8.5
# 221                                         Cars    John Lasseter     7.1
# 935  Talladega Nights: The Ballad of Ricky Bobby       Adam McKay     6.6
# 869                      Mission: Impossible III      J.J. Abrams     6.9
# ..                                           ...              ...     ...
# 206                                     Raw (II)  Julia Ducournau     7.5
# 202                                      Snowden     Oliver Stone     7.3
# 201                          A Cure for Wellness   Gore Verbinski     6.5
# 196                                       Hacker     Akan Satayev     6.3
# 484                                  Angry Birds      Clay Kaytis     6.3
#
#      Year
# 593  2006
# ...

# %% [raw]
# 8. Dealing with missing values

# %%
df.isna().sum() #detect missing values
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.isnull().sum() #check missing values
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [raw]
# 9. Dropping columns and null values

# %%
df.drop("Description", axis = 1)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                  Director                                             Actors  \
# 0              James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %% [raw]
# 10. Apply( ) functions

# %%
df.groupby("Director")[["Rating", "Metascore"]].agg([np.mean, np.median, np.sum])
# Out:
#                     Rating              Metascore
#                       mean median   sum      mean median    sum
# Director
# Aamir Khan            8.50   8.50   8.5      42.0   42.0   42.0
# Abdellatif Kechiche   7.80   7.80   7.8      88.0   88.0   88.0
# Adam Leon             6.50   6.50   6.5      77.0   77.0   77.0
# Adam McKay            7.00   6.80  28.0      65.5   65.0  262.0
# Adam Shankman         6.30   6.30  12.6      64.0   64.0  128.0
# ...                    ...    ...   ...       ...    ...    ...
# Xavier Dolan          7.55   7.55  15.1      61.0   61.0  122.0
# Yimou Zhang           6.10   6.10   6.1      42.0   42.0   42.0
# Yorgos Lanthimos      7.20   7.20  14.4      77.5   77.5  155.0
# Zack Snyder           7.04   7.10  35.2      48.0   52.0  240.0
# Zackary Adler         5.10   5.10   5.1      90.0   90.0   90.0
#
# [644 rows x 6 columns]

# %%
df.mean()
# Out:
# Rank                     500.500000
# Year                    2012.783000
# Runtime (Minutes)        113.172000
# Rating                     6.723200
# Votes                 169808.255000
# Revenue (Millions)        82.956376
# Metascore                 58.985043
# dtype: float64

# %%
df.sort_index(axis = 1)
# Out:
#                                                 Actors  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...
# ..                                                 ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996  Lauren German, Heather Matarazzo, Bijou Philli...
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.sort_values("Votes")
# Out:
#      Rank                     Title                    Genre  \
# 478   479            Paint It Black                    Drama
# 293   294             The Exception                    Drama
# 393   394             Whisky Galore           Comedy,Romance
# 337   338                 Tracktown              Drama,Sport
# 416   417  The Headhunter's Calling                    Drama
# ..    ...                       ...                      ...
# 76     77              The Avengers            Action,Sci-Fi
# 36     37              Interstellar   Adventure,Drama,Sci-Fi
# 124   125     The Dark Knight Rises          Action,Thriller
# 80     81                 Inception  Action,Adventure,Sci-Fi
# 54     55           The Dark Knight       Action,Crime,Drama
#
#                                            Description           Director  \
# 478  A young woman attempts to deal with the death ...      Amber Tamblyn
# 293  A German soldier tries to determine if the Dut...      David Leveaux
# ...
